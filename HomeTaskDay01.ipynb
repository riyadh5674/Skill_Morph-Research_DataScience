# %% [markdown]
# <a href="https://colab.research.google.com/github/riyadh5674/Skill_Morph-Research_DataScience/blob/main/HomeTaskDay01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab & `Github`
#   ```Riyadh```

# %%
# I know Hello world let's print something else !
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2, 4, 200)
y = np.exp(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='e^x')
plt.title('My learning curve | Riyadh')
plt.xlabel('Days')
plt.ylabel('Topics in different fields')
plt.legend()
plt.grid(True)

plt.show()
